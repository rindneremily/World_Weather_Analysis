# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

# Import the API key.
from config import g_key

# %%
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  New Norfolk -42.78  147.06     51.01        69          34
# 1        1   Chokurdakh  70.63  147.92     -4.67        92          98
# 2        2      Waipawa -41.41  175.52     61.00        72           6
# 3        3    Taoudenni  22.68   -3.98     81.73        16         100
# 4        4    Sinnamary   5.38  -52.95     84.22        71         100
#
#    Wind Speed Country                 Date
# 0        2.42      AU  2020-10-31 19:45:46
# 1        7.90      RU  2020-10-31 19:48:27
# 2       16.11      NZ  2020-10-31 19:48:27
# 3       10.63      ML  2020-10-31 19:48:27
# 4       11.86      GF  2020-10-31 19:48:28

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
#for temp in max_temp:
    #temps.append(max(temp, 0))

#heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
# heat_layer = gmaps.heatmap_layer(locations, weights=temps)
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)


# Add the heatmap layer.
fig.add_layer(heat_layer)


fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudy
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
weight=clouds
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent windy
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
weights=wind
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 3         3      Taoudenni  22.68   -3.98     81.73        16         100
# 4         4      Sinnamary   5.38  -52.95     84.22        71         100
# 5         5  Santa Barbara  34.73 -120.03     87.01        18           1
# 6         6           Dire  12.28  -10.97     80.04        42          71
# 8         8         Touros  -5.20  -35.46     84.20        70          40
# 10       10           Mana   5.66  -53.78     85.10        69          62
# 11       11         Avarua -21.21 -159.78     75.20        78         100
# 14       14         Dunkwa   5.97   -1.78     75.29        93          54
# 15       15        Rikitea -23.12 -134.97     75.24        69           0
# 23       23          Kapaa  22.08 -159.32     82.00        78           1
#
#     Wind Speed Country                 Date
# 3        10.63      ML  2020-10-31 19:48:27
# 4        11.86      GF  2020-10-31 19:48:28
# 5         3.36      US  2020-10-31 19:48:28
# 6         2.57      ML  2020-10-31 19:48:28
# 8        14.99      BR  2020-10-31 19:46:31
# 10       14.07      GF  2020-10-31 19:48:29
# 11       10.29      CK  2020-10-31 19:48:29
# 14        2.53      GH  2020-10-31 19:48:29
# 15        6.87      PF  2020-10-31 19:48:30
# 23        6.87      US  2020-10-31 19:47:50

# %%
preferred_cities_df.count()
# Out:
# City_ID       166
# City          166
# Lat           166
# Lng           166
# Max Temp      166
# Humidity      166
# Cloudiness    166
# Wind Speed    166
# Country       165
# Date          166
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp    Lat     Lng Hotel Name
# 3       Taoudenni      ML     81.73  22.68   -3.98
# 4       Sinnamary      GF     84.22   5.38  -52.95
# 5   Santa Barbara      US     87.01  34.73 -120.03
# 6            Dire      ML     80.04  12.28  -10.97
# 8          Touros      BR     84.20  -5.20  -35.46
# 10           Mana      GF     85.10   5.66  -53.78
# 11         Avarua      CK     75.20 -21.21 -159.78
# 14         Dunkwa      GH     75.29   5.97   -1.78
# 15        Rikitea      PF     75.24 -23.12 -134.97
# 23          Kapaa      US     82.00  22.08 -159.32

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart Hotel Paris)</a>'], 'photo_reference': 'CmRaAAAA7Zb_1-N4hfgU5G_gs583IMoS6iuiiLIai6Iu4kh0Qv-Ll1gDUc0cZLu5nHdV2-akC8oN78XccSrlMNgjc8X2vHPUguysMgw1kdZAaH7dJ6jfvLRTT-6cPATd0JCojl43EhBCPYjzrwXPZvl41iRTBj1KGhQ10zSd2uyX7yjQqWuyGSiWOu4bLg', 'width': 745}], 'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'plus_code': {'compound_code': 'V86W+7Q Paris, France', 'global_code': '8FW4V86W+7Q'}, 'rating': 4.1, 'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 815, 'vicinity': '4 Rue des Innocents, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48. ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    #print(lat)
    #print(lng)
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #print(base_url)
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    #print(hotels)
    # Grab the first hotel from the results and store the name.
    #hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (KeyError, IndexError):
        print("Hotel not found... skipping.")
print(hotel_df)
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#               City Country  Max Temp    Lat     Lng  \
# 3        Taoudenni      ML     81.73  22.68   -3.98
# 4        Sinnamary      GF     84.22   5.38  -52.95
# 5    Santa Barbara      US     87.01  34.73 -120.03
# 6             Dire      ML     80.04  12.28  -10.97
# 8           Touros      BR     84.20  -5.20  -35.46
# ..             ...     ...       ...    ...     ...
# 535          Guane      CU     85.24  22.20  -84.09
# 540          Kanbe      MM     77.00  16.71   96.00
# 542        Karaton      ID     80.01  -6.34  106.10
# 543          Alofi      NU     75.20 -19.06 -169.92
# 545   Port Moresby      PG     77.00  -9.44  147.18
#
#                                 Hotel Name
# 3
# 4           ALETHEIA Appartement Sinnamary
# 5                 Upper Ballard Campground
# 6
# 8                          INN NEW HORIZON
# ..                                     ...
# 535  base de Campismo LosPortales de Guane
# 540            CBT Mingalar Bar Bio Garden
# 542     Parkir Mobil Wisata CAS Water Park
# 543                          Taloa Heights
# 545                           Lamana Hotel
#
# [166 rows x 6 columns]

# %%
hotel_df
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 3        Taoudenni      ML     81.73  22.68   -3.98
# 4        Sinnamary      GF     84.22   5.38  -52.95
# 5    Santa Barbara      US     87.01  34.73 -120.03
# 6             Dire      ML     80.04  12.28  -10.97
# 8           Touros      BR     84.20  -5.20  -35.46
# ..             ...     ...       ...    ...     ...
# 535          Guane      CU     85.24  22.20  -84.09
# 540          Kanbe      MM     77.00  16.71   96.00
# 542        Karaton      ID     80.01  -6.34  106.10
# 543          Alofi      NU     75.20 -19.06 -169.92
# 545   Port Moresby      PG     77.00  -9.44  147.18
#
#                                 Hotel Name
# 3
# 4           ALETHEIA Appartement Sinnamary
# 5                 Upper Ballard Campground
# 6
# 8                          INN NEW HORIZON
# ..                                     ...
# 535  base de Campismo LosPortales de Guane
# 540            CBT Mingalar Bar Bio Garden
# 542     Parkir Mobil Wisata CAS Water Park
# 543                          Taloa Heights
# 545                           Lamana Hotel
#
# [166 rows x 6 columns]
